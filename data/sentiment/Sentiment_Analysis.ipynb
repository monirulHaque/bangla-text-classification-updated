# %%
import pandas as pd
obj = pd.read_pickle('test.pickle')
obj
# Out:
# [['ঢাকা চেম্বার অব কমার্স অ্যান্ড ইন্ডাস্ট্রির (ডিসিসিআই) সভাপতি আবুল কাসেম খান বলেন, জার্মানির মতো দেশগুলো তাদের শিল্পের কী চাহিদা, সে অনুযায়ী জনশক্তি তৈরি করে। বাংলাদেশেও সেটা দরকার।',
#   1,
#   6711],
#  ['আমি মনে করি সাব্বির কে বাদ দিয়ে নতুন একজন ভালো মানের খেলোয়ার প্রয়োজন বাংলাদেশ টিমে তাহলে এই দিনের মত আমাদের আর হারতে হবে না',
#   0,
#   10092],
#  ['সরকার জেনে গেছে সুষ্ঠু ভোট হলে পরাজয় নিশ্চিত।', 0, 13398],
#  ['এদের এই মারামারিতে তো আমাদের মাথা ব্যথায় টনটন করে', 0, 2879],
#  ['অধিকাংশ রাষ্ট্রায়ত্ত ব্যাংকেই সরকার প্রতি বছর ভর্তুকি দিয়ে যাচ্ছে আর জনগণের করের টাকা রাঘব-বোয়ালরা লুটে নিচ্ছে। সবকিছু রাজনৈতিক শক্তির চোখের সামনেই ঘটছে। এবং এ ইতিহাস অনেক দিনের। কোন সরকারই এই ব্যাংকগুলোকে লাভজনক হিসেবে গড়ে তুলতে কার্যকর পদক্ষেপ নেয় নি। ব্যাংকগুলোকে ব্যবহার করা হয়েছে গুন্ডা-পান্ডা ও চোর-বাটপারদের মোটাতাজা করার হাতিয়ার হিসেবে।',
#   0,
#   8332],
# ...

# %%
type(obj)
# Out:
# list

# %%
df = pd.DataFrame(obj)
df
# Out:
#                                                       0  1      2
# 0     ঢাকা চেম্বার অব কমার্স অ্যান্ড ইন্ডাস্ট্রির (ড...  1   6711
# 1     আমি মনে করি সাব্বির কে বাদ দিয়ে নতুন একজন ভালো...  0  10092
# 2         সরকার জেনে গেছে সুষ্ঠু ভোট হলে পরাজয় নিশ্চিত।  0  13398
# 3     এদের এই মারামারিতে তো আমাদের মাথা ব্যথায় টনটন করে  0   2879
# 4     অধিকাংশ রাষ্ট্রায়ত্ত ব্যাংকেই সরকার প্রতি বছর ...  0   8332
# ...                                                 ... ..    ...
# 1081  পক্ষে গেলে ন্যায় আর পক্ষে না গেলে অন্যায় যা ...  0   4596
# 1082  বিএনপি/জামাত আমলেও তারা দুর্দান্ত ব্যবসা করছিল...  0   8014
# 1083  ভাল। তবে আরো ভাল হতো- সমান টাকা খরচ করে, দেশে ...  1   8191
# 1084              এর সত্যতা নেই। মিয়ানমারের মৌখিক দাবি।  0   2880
# 1085  ঢাকা ইপিজেড এলাকার আশপাশের ২০ কিলোমিটার রাস্তা...  1   1254
#
# [1086 rows x 3 columns]
